# %% [markdown]
# # Deprecated — use split ICARUS AE notebooks
#
# - VAE (slice A): `train/04a_TrainVAE_ICARUS.ipynb`
# - CAE (slice B): `train/04b_TrainCAE_ICARUS.ipynb`
#
# Stop leftover diffusion trainers on EAF:
# ```bash
# bash train/stop_running_trainers.sh
# rm -f STOP_TRAINING
# ```
