# %% [markdown]
# # Insert synthetic detector defects (unhealthy datasets)
#
# **Kernel:** `env` or analysis kernel with numpy/scipy.
#
# Canonical CLI (preferred over the exploratory `MakeDetectorFeatures.ipynb`)::
#
#     python samples/apply_detector_defects_npz.py --input-dir <healthy_npz_dir>
#
# Creates sibling dirs ``<dir>_bad_wire``, ``<dir>_coh_noise``, ``<dir>_charge_tail`` (+ `_defect` maps).
# Write durable copies under `/exp/sbnd/data/.../samples/defects/`.

# %%
from pathlib import Path
import sys
sys.path.insert(0, "/exp/sbnd/app/users/munjung/anomaly-detection")
from configs.paths import SAMPLES_NPZ, SAMPLES_DEFECTS, DEFECT_TYPES, ensure_layout
ensure_layout()
print("defect types:", DEFECT_TYPES)
print("npz in :", SAMPLES_NPZ)
print("defects out:", SAMPLES_DEFECTS)
print('''
Example:
  python samples/apply_detector_defects_npz.py \
      --input-dir /exp/sbnd/data/users/munjung/anomaly-detection/samples/npz/plane1_healthy
''')
