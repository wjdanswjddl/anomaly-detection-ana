# %% [markdown]
# # Inspect samples & handscan interesting / unhealthy events
#
# **Kernel:** `env`
#
# Consolidates the former `inspect_samples*.ipynb` and `HandscanUnhealthy.ipynb` entry points.
# Detailed handscan UI still lives in `samples/HandscanUnhealthy.ipynb`; preparation / analysis of the
# labeled validation set is archived under `archive/notebooks/PrepareHandscanValidation.ipynb` etc.
#
# Data:
# - H5: `/exp/sbnd/data/.../samples/h5`
# - Handscan archives: `/exp/sbnd/data/.../archive/handscan_archives`
# - Validation set: `/exp/sbnd/data/.../samples/handscan/validation` (symlink: repo `handscan_validation`)

# %%
from pathlib import Path
import sys
sys.path.insert(0, "/exp/sbnd/app/users/munjung/anomaly-detection")
from configs.paths import SAMPLES_H5, SAMPLES_HANDSCAN, HANDSCAN_VALIDATION, ARCHIVE_DATA, ensure_layout
ensure_layout()
print("h5           ", SAMPLES_H5, "n=", len(list(SAMPLES_H5.glob('*.h5'))))
print("handscan     ", SAMPLES_HANDSCAN)
print("validation   ", HANDSCAN_VALIDATION, "exists=", HANDSCAN_VALIDATION.exists())
print("old archives ", ARCHIVE_DATA / "handscan_archives")
# Open samples/HandscanUnhealthy.ipynb for the interactive archive workflow.
# Open samples/inspect_samples.ipynb / h5_to_npz.ipynb for format conversion.
